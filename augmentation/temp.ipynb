# %%
import pandas  as pd
import os 
import json
os.chdir("../")
os.getcwd()
# Out:
# '/workspace'

# %%
with open ("data/COCO/Annotations/coco_img_info_0.01_bbox_center_0.7.json") as f:
    image_caption = json.load(f)

# %%
image_caption
# Out:
# {'57870': {'file_name': 'COCO_train2014_000000057870.jpg',
#   'width': 640,
#   'height': 480,
#   'objects_count': 17,
#   'max_obj_id': 2190436,
#   'max_obj_cat_id': 62,
#   'max_obj_super_cat': ['furniture', 'furnitures'],
#   'max_obj_cat': ['chair', 'chairs'],
#   'max_obj_area': 23717.007900000004,
#   'max_obj_midpoint': [176.59, 375.745],
#   'max_obj_bbox': [90.67, 271.49, 171.84, 208.51],
#   'max_obj_area_portion': 0.07720380175781251,
#   'captions': ['A restaurant has modern wooden tables and chairs.',
#    'A long restaurant table with rattan rounded back chairs.',
#    'a long table with a plant on top of it surrounded with wooden chairs ',
#    'A long table with a flower arrangement in the middle for meetings',
#    'A table is adorned with wooden chairs with blue accents.'],
#   'obj_bg': 'obj'},
#  '384029': {'file_name': 'COCO_train2014_000000384029.jpg',
#   'width': 640,
#   'height': 429,
#   'objects_count': 14,
#   'max_obj_id': 423921,
# ...

# %%
import random

# %%
#random pick caption
random_caption = random.choice(image_caption["57870"]["captions"])

# %%
random_caption
# Out:
# 'A restaurant has modern wooden tables and chairs.'

# %%
image_caption["57870"]["max_obj_cat"] + image_caption["57870"]["max_obj_super_cat"]
# Out:
# ['chair', 'chairs', 'furniture', 'furnitures']

# %%
image_caption["57870"]["max_obj_super_cat"]
# Out:
# ['furniture', 'furnitures']
